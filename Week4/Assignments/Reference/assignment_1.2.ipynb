# %% [markdown]
# # 手写识别回顾

# %% [markdown]
# **说明:**
#
# 将 `/trainingDigits` 和 `/testDigits` 放在当前目录下。

# %%
from numpy import *
from time import sleep

# %%
def loadDataSet(fileName):
    dataMat = []; labelMat = []
    fr = open(fileName)
    for line in fr.readlines():
        lineArr = line.strip().split('\t')
        dataMat.append([float(lineArr[0]), float(lineArr[1])])
        labelMat.append(float(lineArr[2]))
    return dataMat,labelMat

def selectJrand(i,m):
    j=i #we want to select any J not equal to i
    while (j==i):
        j = int(random.uniform(0,m))
    return j

def clipAlpha(aj,H,L):
    if aj > H: 
        aj = H
    if L > aj:
        aj = L
    return aj

# %% [markdown]
# ## 定义核转换函数

# %%
def kernelTrans(X, A, kTup): #calc the kernel or transform data to a higher dimensional space
    m,n = shape(X)
    K = mat(zeros((m,1)))
    if kTup[0]=='lin': K = X * A.T   #linear kernel
    elif kTup[0]=='rbf':
        for j in range(m):
            deltaRow = X[j,:] - A
            K[j] = deltaRow*deltaRow.T
        K = exp(K/(-1*kTup[1]**2)) #divide in NumPy is element-wise not matrix like Matlab
    else: raise NameError('Houston We Have a Problem -- \
    That Kernel is not recognized')
    return K

# %% [markdown]
# ## 定义完整版 Platt SMO 支持函数

# %%
class optStruct:
    def __init__(self,dataMatIn, classLabels, C, toler, kTup):  # Initialize the structure with the parameters 
        self.X = dataMatIn
        self.labelMat = classLabels
        self.C = C
        self.tol = toler
        self.m = shape(dataMatIn)[0]
        self.alphas = mat(zeros((self.m,1)))
        self.b = 0
        self.eCache = mat(zeros((self.m,2))) #first column is valid flag
        self.K = mat(zeros((self.m,self.m)))
        for i in range(self.m):
            self.K[:,i] = kernelTrans(self.X, self.X[i,:], kTup)

def calcEk(oS, k):
    fXk = float(multiply(oS.alphas,oS.labelMat).T*oS.K[:,k] + oS.b)
    Ek = fXk - float(oS.labelMat[k])
    return Ek
        
def selectJ(i, oS, Ei):         #this is the second choice -heurstic, and calcs Ej
    maxK = -1; maxDeltaE = 0; Ej = 0
    oS.eCache[i] = [1,Ei]  #set valid #choose the alpha that gives the maximum delta E
    validEcacheList = nonzero(oS.eCache[:,0].A)[0]
    if (len(validEcacheList)) > 1:
        for k in validEcacheList:   #loop through valid Ecache values and find the one that maximizes delta E
            if k == i: continue #don't calc for i, waste of time
            Ek = calcEk(oS, k)
            deltaE = abs(Ei - Ek)
            if (deltaE > maxDeltaE):
                maxK = k; maxDeltaE = deltaE; Ej = Ek
        return maxK, Ej
    else:   #in this case (first time around) we don't have any valid eCache values
        j = selectJrand(i, oS.m)
        Ej = calcEk(oS, j)
    return j, Ej

def updateEk(oS, k):#after any alpha has changed update the new value in the cache
    Ek = calcEk(oS, k)
    oS.eCache[k] = [1,Ek]

# %% [markdown]
# ## 定义完整版 Platt SMO 算法优化例程

# %%
def innerL(i, oS):
    Ei = calcEk(oS, i)
    if ((oS.labelMat[i]*Ei < -oS.tol) and (oS.alphas[i] < oS.C)) or ((oS.labelMat[i]*Ei > oS.tol) and (oS.alphas[i] > 0)):
        j,Ej = selectJ(i, oS, Ei) #this has been changed from selectJrand
        alphaIold = oS.alphas[i].copy(); alphaJold = oS.alphas[j].copy();
        if (oS.labelMat[i] != oS.labelMat[j]):
            L = max(0, oS.alphas[j] - oS.alphas[i])
            H = min(oS.C, oS.C + oS.alphas[j] - oS.alphas[i])
        else:
            L = max(0, oS.alphas[j] + oS.alphas[i] - oS.C)
            H = min(oS.C, oS.alphas[j] + oS.alphas[i])
        if L==H: print("L==H"); return 0
        eta = 2.0 * oS.K[i,j] - oS.K[i,i] - oS.K[j,j] #changed for kernel
        if eta >= 0: print("eta>=0"); return 0
        oS.alphas[j] -= oS.labelMat[j]*(Ei - Ej)/eta
        oS.alphas[j] = clipAlpha(oS.alphas[j],H,L)
        updateEk(oS, j) #added this for the Ecache
        if (abs(oS.alphas[j] - alphaJold) < 0.00001): print("j not moving enough"); return 0
        oS.alphas[i] += oS.labelMat[j]*oS.labelMat[i]*(alphaJold - oS.alphas[j])#update i by the same amount as j
        updateEk(oS, i) #added this for the Ecache                    #the update is in the oppostie direction
        b1 = oS.b - Ei- oS.labelMat[i]*(oS.alphas[i]-alphaIold)*oS.K[i,i] - oS.labelMat[j]*(oS.alphas[j]-alphaJold)*oS.K[i,j]
        b2 = oS.b - Ej- oS.labelMat[i]*(oS.alphas[i]-alphaIold)*oS.K[i,j]- oS.labelMat[j]*(oS.alphas[j]-alphaJold)*oS.K[j,j]
        if (0 < oS.alphas[i]) and (oS.C > oS.alphas[i]): oS.b = b1
        elif (0 < oS.alphas[j]) and (oS.C > oS.alphas[j]): oS.b = b2
        else: oS.b = (b1 + b2)/2.0
        return 1
    else: return 0

# %% [markdown]
# ## 定义完整版 Platt SMO 的外循环代码

# %%
def smoP(dataMatIn, classLabels, C, toler, maxIter,kTup=('lin', 0)):    #full Platt SMO
    oS = optStruct(mat(dataMatIn),mat(classLabels).transpose(),C,toler, kTup)
    iter = 0
    entireSet = True; alphaPairsChanged = 0
    while (iter < maxIter) and ((alphaPairsChanged > 0) or (entireSet)):
        alphaPairsChanged = 0
        if entireSet:   #go over all
            for i in range(oS.m):        
                alphaPairsChanged += innerL(i,oS)
                print("fullSet, iter: %d i:%d, pairs changed %d" % (iter,i,alphaPairsChanged))
            iter += 1
        else:#go over non-bound (railed) alphas
            nonBoundIs = nonzero((oS.alphas.A > 0) * (oS.alphas.A < C))[0]
            for i in nonBoundIs:
                alphaPairsChanged += innerL(i,oS)
                print("non-bound, iter: %d i:%d, pairs changed %d" % (iter,i,alphaPairsChanged))
            iter += 1
        if entireSet: entireSet = False #toggle entire set loop
        elif (alphaPairsChanged == 0): entireSet = True  
        print("iteration number: %d" % iter)
    return oS.b,oS.alphas

# %% [markdown]
# ## 利用核函数进行分类的径向基测试函数

# %%
def testRbf(k1=1.3):
    dataArr,labelArr = loadDataSet('testSetRBF.txt')
    b,alphas = smoP(dataArr, labelArr, 200, 0.0001, 10000, ('rbf', k1)) #C=200 important
    datMat=mat(dataArr); labelMat = mat(labelArr).transpose()
    svInd=nonzero(alphas.A>0)[0]
    sVs=datMat[svInd] #get matrix of only support vectors
    labelSV = labelMat[svInd];
    print("there are %d Support Vectors" % shape(sVs)[0])
    m,n = shape(datMat)
    errorCount = 0
    for i in range(m):
        kernelEval = kernelTrans(sVs,datMat[i,:],('rbf', k1))
        predict=kernelEval.T * multiply(labelSV,alphas[svInd]) + b
        if sign(predict)!=sign(labelArr[i]): errorCount += 1
    print("the training error rate is: %f" % (float(errorCount)/m))
    dataArr,labelArr = loadDataSet('testSetRBF2.txt')
    errorCount = 0
    datMat=mat(dataArr); labelMat = mat(labelArr).transpose()
    m,n = shape(datMat)
    for i in range(m):
        kernelEval = kernelTrans(sVs,datMat[i,:],('rbf', k1))
        predict=kernelEval.T * multiply(labelSV,alphas[svInd]) + b
        if sign(predict)!=sign(labelArr[i]): errorCount += 1    
    print("the test error rate is: %f" % (float(errorCount)/m))

# %%
testRbf()
# Out:
# fullSet, iter: 0 i:0, pairs changed 1
# fullSet, iter: 0 i:1, pairs changed 2
# fullSet, iter: 0 i:2, pairs changed 3
# fullSet, iter: 0 i:3, pairs changed 4
# fullSet, iter: 0 i:4, pairs changed 5
# fullSet, iter: 0 i:5, pairs changed 6
# fullSet, iter: 0 i:6, pairs changed 6
# fullSet, iter: 0 i:7, pairs changed 7
# fullSet, iter: 0 i:8, pairs changed 8
# fullSet, iter: 0 i:9, pairs changed 8
# L==H
# fullSet, iter: 0 i:10, pairs changed 8
# fullSet, iter: 0 i:11, pairs changed 9
# fullSet, iter: 0 i:12, pairs changed 9
# fullSet, iter: 0 i:13, pairs changed 10
# L==H
# fullSet, iter: 0 i:14, pairs changed 10
# fullSet, iter: 0 i:15, pairs changed 11
# fullSet, iter: 0 i:16, pairs changed 12
# L==H
# fullSet, iter: 0 i:17, pairs changed 12
# fullSet, iter: 0 i:18, pairs changed 13
# fullSet, iter: 0 i:19, pairs changed 14
# fullSet, iter: 0 i:20, pairs changed 14
# L==H
# fullSet, iter: 0 i:21, pairs changed 14
# fullSet, iter: 0 i:22, pairs changed 14
# fullSet, iter: 0 i:23, pairs changed 15
# fullSet, iter: 0 i:24, pairs changed 16
# fullSet, iter: 0 i:25, pairs changed 16
# fullSet, iter: 0 i:26, pairs changed 17
# fullSet, iter: 0 i:27, pairs changed 18
# fullSet, iter: 0 i:28, pairs changed 19
# fullSet, iter: 0 i:29, pairs changed 20
# fullSet, iter: 0 i:30, pairs changed 20
# fullSet, iter: 0 i:31, pairs changed 21
# fullSet, iter: 0 i:32, pairs changed 21
# fullSet, iter: 0 i:33, pairs changed 21
# fullSet, iter: 0 i:34, pairs changed 21
# fullSet, iter: 0 i:35, pairs changed 21
# L==H
# fullSet, iter: 0 i:36, pairs changed 21
# fullSet, iter: 0 i:37, pairs changed 21
# L==H
# fullSet, iter: 0 i:38, pairs changed 21
# fullSet, iter: 0 i:39, pairs changed 21
# fullSet, iter: 0 i:40, pairs changed 21
# L==H
# fullSet, iter: 0 i:41, pairs changed 21
# L==H
# fullSet, iter: 0 i:42, pairs changed 21
# L==H
# fullSet, iter: 0 i:43, pairs changed 21
# fullSet, iter: 0 i:44, pairs changed 21
# fullSet, iter: 0 i:45, pairs changed 22
# L==H
# fullSet, iter: 0 i:46, pairs changed 22
# fullSet, iter: 0 i:47, pairs changed 22
# L==H
# fullSet, iter: 0 i:48, pairs changed 22
# fullSet, iter: 0 i:49, pairs changed 22
# j not moving enough
# fullSet, iter: 0 i:50, pairs changed 22
# fullSet, iter: 0 i:51, pairs changed 22
# fullSet, iter: 0 i:52, pairs changed 22
# L==H
# fullSet, iter: 0 i:53, pairs changed 22
# fullSet, iter: 0 i:54, pairs changed 22
# fullSet, iter: 0 i:55, pairs changed 22
# j not moving enough
# fullSet, iter: 0 i:56, pairs changed 22
# L==H
# fullSet, iter: 0 i:57, pairs changed 22
# L==H
# fullSet, iter: 0 i:58, pairs changed 22
# fullSet, iter: 0 i:59, pairs changed 22
# fullSet, iter: 0 i:60, pairs changed 22
# j not moving enough
# fullSet, iter: 0 i:61, pairs changed 22
# fullSet, iter: 0 i:62, pairs changed 22
# fullSet, iter: 0 i:63, pairs changed 22
# fullSet, iter: 0 i:64, pairs changed 22
# L==H
# fullSet, iter: 0 i:65, pairs changed 22
# L==H
# fullSet, iter: 0 i:66, pairs changed 22
# fullSet, iter: 0 i:67, pairs changed 22
# fullSet, iter: 0 i:68, pairs changed 22
# fullSet, iter: 0 i:69, pairs changed 22
# fullSet, iter: 0 i:70, pairs changed 22
# fullSet, iter: 0 i:71, pairs changed 22
# fullSet, iter: 0 i:72, pairs changed 22
# fullSet, iter: 0 i:73, pairs changed 22
# j not moving enough
# fullSet, iter: 0 i:74, pairs changed 22
# fullSet, iter: 0 i:75, pairs changed 22
# L==H
# fullSet, iter: 0 i:76, pairs changed 22
# fullSet, iter: 0 i:77, pairs changed 22
# L==H
# fullSet, iter: 0 i:78, pairs changed 22
# L==H
# fullSet, iter: 0 i:79, pairs changed 22
# fullSet, iter: 0 i:80, pairs changed 22
# L==H
# fullSet, iter: 0 i:81, pairs changed 22
# L==H
# fullSet, iter: 0 i:82, pairs changed 22
# fullSet, iter: 0 i:83, pairs changed 22
# fullSet, iter: 0 i:84, pairs changed 22
# fullSet, iter: 0 i:85, pairs changed 22
# fullSet, iter: 0 i:86, pairs changed 22
# L==H
# fullSet, iter: 0 i:87, pairs changed 22
# fullSet, iter: 0 i:88, pairs changed 22
# fullSet, iter: 0 i:89, pairs changed 22
# L==H
# fullSet, iter: 0 i:90, pairs changed 22
# fullSet, iter: 0 i:91, pairs changed 22
# L==H
# fullSet, iter: 0 i:92, pairs changed 22
# fullSet, iter: 0 i:93, pairs changed 22
# fullSet, iter: 0 i:94, pairs changed 22
# fullSet, iter: 0 i:95, pairs changed 22
# fullSet, iter: 0 i:96, pairs changed 22
# fullSet, iter: 0 i:97, pairs changed 22
# fullSet, iter: 0 i:98, pairs changed 22
# fullSet, iter: 0 i:99, pairs changed 22
# iteration number: 1
# j not moving enough
# non-bound, iter: 1 i:0, pairs changed 0
# j not moving enough
# non-bound, iter: 1 i:1, pairs changed 0
# j not moving enough
# non-bound, iter: 1 i:2, pairs changed 0
# j not moving enough
# non-bound, iter: 1 i:3, pairs changed 0
# j not moving enough
# non-bound, iter: 1 i:7, pairs changed 0
# j not moving enough
# non-bound, iter: 1 i:8, pairs changed 0
# j not moving enough
# non-bound, iter: 1 i:11, pairs changed 0
# j not moving enough
# non-bound, iter: 1 i:13, pairs changed 0
# j not moving enough
# non-bound, iter: 1 i:14, pairs changed 0
# non-bound, iter: 1 i:15, pairs changed 1
# j not moving enough
# non-bound, iter: 1 i:16, pairs changed 1
# j not moving enough
# non-bound, iter: 1 i:17, pairs changed 1
# non-bound, iter: 1 i:18, pairs changed 2
# non-bound, iter: 1 i:19, pairs changed 3
# j not moving enough
# non-bound, iter: 1 i:21, pairs changed 3
# j not moving enough
# non-bound, iter: 1 i:23, pairs changed 3
# non-bound, iter: 1 i:24, pairs changed 4
# non-bound, iter: 1 i:26, pairs changed 5
# j not moving enough
# non-bound, iter: 1 i:27, pairs changed 5
# j not moving enough
# non-bound, iter: 1 i:28, pairs changed 5
# non-bound, iter: 1 i:29, pairs changed 6
# j not moving enough
# non-bound, iter: 1 i:31, pairs changed 6
# j not moving enough
# non-bound, iter: 1 i:45, pairs changed 6
# iteration number: 2
# j not moving enough
# non-bound, iter: 2 i:0, pairs changed 0
# j not moving enough
# non-bound, iter: 2 i:1, pairs changed 0
# non-bound, iter: 2 i:2, pairs changed 1
# j not moving enough
# non-bound, iter: 2 i:3, pairs changed 1
# j not moving enough
# non-bound, iter: 2 i:7, pairs changed 1
# j not moving enough
# non-bound, iter: 2 i:8, pairs changed 1
# j not moving enough
# non-bound, iter: 2 i:11, pairs changed 1
# j not moving enough
# non-bound, iter: 2 i:13, pairs changed 1
# j not moving enough
# non-bound, iter: 2 i:14, pairs changed 1
# j not moving enough
# non-bound, iter: 2 i:16, pairs changed 1
# j not moving enough
# non-bound, iter: 2 i:17, pairs changed 1
# non-bound, iter: 2 i:18, pairs changed 2
# non-bound, iter: 2 i:19, pairs changed 3
# non-bound, iter: 2 i:21, pairs changed 3
# j not moving enough
# non-bound, iter: 2 i:23, pairs changed 3
# non-bound, iter: 2 i:26, pairs changed 4
# j not moving enough
# non-bound, iter: 2 i:27, pairs changed 4
# j not moving enough
# non-bound, iter: 2 i:28, pairs changed 4
# j not moving enough
# non-bound, iter: 2 i:29, pairs changed 4
# j not moving enough
# non-bound, iter: 2 i:31, pairs changed 4
# non-bound, iter: 2 i:45, pairs changed 5
# non-bound, iter: 2 i:48, pairs changed 6
# non-bound, iter: 2 i:76, pairs changed 6
# j not moving enough
# non-bound, iter: 2 i:87, pairs changed 6
# iteration number: 3
# non-bound, iter: 3 i:0, pairs changed 1
# non-bound, iter: 3 i:1, pairs changed 1
# j not moving enough
# non-bound, iter: 3 i:3, pairs changed 1
# j not moving enough
# non-bound, iter: 3 i:7, pairs changed 1
# non-bound, iter: 3 i:8, pairs changed 2
# j not moving enough
# non-bound, iter: 3 i:11, pairs changed 2
# j not moving enough
# non-bound, iter: 3 i:13, pairs changed 2
# j not moving enough
# non-bound, iter: 3 i:14, pairs changed 2
# non-bound, iter: 3 i:16, pairs changed 3
# j not moving enough
# non-bound, iter: 3 i:17, pairs changed 3
# j not moving enough
# non-bound, iter: 3 i:18, pairs changed 3
# j not moving enough
# non-bound, iter: 3 i:19, pairs changed 3
# j not moving enough
# non-bound, iter: 3 i:21, pairs changed 3
# j not moving enough
# non-bound, iter: 3 i:23, pairs changed 3
# j not moving enough
# non-bound, iter: 3 i:26, pairs changed 3
# j not moving enough
# non-bound, iter: 3 i:27, pairs changed 3
# j not moving enough
# non-bound, iter: 3 i:28, pairs changed 3
# non-bound, iter: 3 i:29, pairs changed 4
# j not moving enough
# non-bound, iter: 3 i:31, pairs changed 4
# j not moving enough
# non-bound, iter: 3 i:36, pairs changed 4
# j not moving enough
# non-bound, iter: 3 i:41, pairs changed 4
# j not moving enough
# non-bound, iter: 3 i:45, pairs changed 4
# j not moving enough
# non-bound, iter: 3 i:76, pairs changed 4
# non-bound, iter: 3 i:87, pairs changed 4
# iteration number: 4
# j not moving enough
# non-bound, iter: 4 i:0, pairs changed 0
# j not moving enough
# non-bound, iter: 4 i:1, pairs changed 0
# j not moving enough
# non-bound, iter: 4 i:3, pairs changed 0
# j not moving enough
# non-bound, iter: 4 i:7, pairs changed 0
# non-bound, iter: 4 i:11, pairs changed 1
# j not moving enough
# non-bound, iter: 4 i:13, pairs changed 1
# j not moving enough
# non-bound, iter: 4 i:14, pairs changed 1
# j not moving enough
# non-bound, iter: 4 i:16, pairs changed 1
# j not moving enough
# non-bound, iter: 4 i:17, pairs changed 1
# j not moving enough
# non-bound, iter: 4 i:18, pairs changed 1
# j not moving enough
# non-bound, iter: 4 i:19, pairs changed 1
# j not moving enough
# non-bound, iter: 4 i:21, pairs changed 1
# non-bound, iter: 4 i:23, pairs changed 2
# j not moving enough
# non-bound, iter: 4 i:26, pairs changed 2
# j not moving enough
# non-bound, iter: 4 i:27, pairs changed 2
# j not moving enough
# non-bound, iter: 4 i:28, pairs changed 2
# non-bound, iter: 4 i:29, pairs changed 3
# j not moving enough
# non-bound, iter: 4 i:31, pairs changed 3
# j not moving enough
# non-bound, iter: 4 i:36, pairs changed 3
# j not moving enough
# non-bound, iter: 4 i:41, pairs changed 3
# non-bound, iter: 4 i:45, pairs changed 4
# j not moving enough
# non-bound, iter: 4 i:76, pairs changed 4
# j not moving enough
# non-bound, iter: 4 i:87, pairs changed 4
# iteration number: 5
# j not moving enough
# non-bound, iter: 5 i:0, pairs changed 0
# j not moving enough
# non-bound, iter: 5 i:1, pairs changed 0
# j not moving enough
# non-bound, iter: 5 i:3, pairs changed 0
# j not moving enough
# non-bound, iter: 5 i:7, pairs changed 0
# j not moving enough
# non-bound, iter: 5 i:11, pairs changed 0
# j not moving enough
# non-bound, iter: 5 i:13, pairs changed 0
# j not moving enough
# non-bound, iter: 5 i:14, pairs changed 0
# j not moving enough
# non-bound, iter: 5 i:16, pairs changed 0
# j not moving enough
# non-bound, iter: 5 i:17, pairs changed 0
# j not moving enough
# non-bound, iter: 5 i:18, pairs changed 0
# j not moving enough
# non-bound, iter: 5 i:19, pairs changed 0
# non-bound, iter: 5 i:21, pairs changed 0
# j not moving enough
# non-bound, iter: 5 i:23, pairs changed 0
# j not moving enough
# non-bound, iter: 5 i:26, pairs changed 0
# j not moving enough
# non-bound, iter: 5 i:27, pairs changed 0
# j not moving enough
# non-bound, iter: 5 i:28, pairs changed 0
# j not moving enough
# non-bound, iter: 5 i:29, pairs changed 0
# j not moving enough
# non-bound, iter: 5 i:31, pairs changed 0
# j not moving enough
# non-bound, iter: 5 i:36, pairs changed 0
# j not moving enough
# non-bound, iter: 5 i:41, pairs changed 0
# non-bound, iter: 5 i:45, pairs changed 0
# j not moving enough
# non-bound, iter: 5 i:76, pairs changed 0
# j not moving enough
# non-bound, iter: 5 i:87, pairs changed 0
# iteration number: 6
# j not moving enough
# fullSet, iter: 6 i:0, pairs changed 0
# j not moving enough
# fullSet, iter: 6 i:1, pairs changed 0
# fullSet, iter: 6 i:2, pairs changed 0
# j not moving enough
# fullSet, iter: 6 i:3, pairs changed 0
# fullSet, iter: 6 i:4, pairs changed 0
# fullSet, iter: 6 i:5, pairs changed 0
# L==H
# fullSet, iter: 6 i:6, pairs changed 0
# j not moving enough
# fullSet, iter: 6 i:7, pairs changed 0
# fullSet, iter: 6 i:8, pairs changed 0
# j not moving enough
# fullSet, iter: 6 i:9, pairs changed 0
# fullSet, iter: 6 i:10, pairs changed 0
# j not moving enough
# fullSet, iter: 6 i:11, pairs changed 0
# fullSet, iter: 6 i:12, pairs changed 0
# j not moving enough
# fullSet, iter: 6 i:13, pairs changed 0
# j not moving enough
# fullSet, iter: 6 i:14, pairs changed 0
# fullSet, iter: 6 i:15, pairs changed 0
# j not moving enough
# fullSet, iter: 6 i:16, pairs changed 0
# j not moving enough
# fullSet, iter: 6 i:17, pairs changed 0
# j not moving enough
# fullSet, iter: 6 i:18, pairs changed 0
# j not moving enough
# fullSet, iter: 6 i:19, pairs changed 0
# fullSet, iter: 6 i:20, pairs changed 0
# fullSet, iter: 6 i:21, pairs changed 0
# fullSet, iter: 6 i:22, pairs changed 0
# j not moving enough
# fullSet, iter: 6 i:23, pairs changed 0
# fullSet, iter: 6 i:24, pairs changed 0
# fullSet, iter: 6 i:25, pairs changed 0
# j not moving enough
# fullSet, iter: 6 i:26, pairs changed 0
# j not moving enough
# fullSet, iter: 6 i:27, pairs changed 0
# j not moving enough
# fullSet, iter: 6 i:28, pairs changed 0
# j not moving enough
# fullSet, iter: 6 i:29, pairs changed 0
# fullSet, iter: 6 i:30, pairs changed 0
# j not moving enough
# fullSet, iter: 6 i:31, pairs changed 0
# fullSet, iter: 6 i:32, pairs changed 0
# fullSet, iter: 6 i:33, pairs changed 0
# fullSet, iter: 6 i:34, pairs changed 1
# fullSet, iter: 6 i:35, pairs changed 1
# j not moving enough
# fullSet, iter: 6 i:36, pairs changed 1
# fullSet, iter: 6 i:37, pairs changed 1
# fullSet, iter: 6 i:38, pairs changed 1
# fullSet, iter: 6 i:39, pairs changed 1
# fullSet, iter: 6 i:40, pairs changed 1
# fullSet, iter: 6 i:41, pairs changed 1
# L==H
# fullSet, iter: 6 i:42, pairs changed 1
# fullSet, iter: 6 i:43, pairs changed 1
# fullSet, iter: 6 i:44, pairs changed 1
# fullSet, iter: 6 i:45, pairs changed 2
# L==H
# fullSet, iter: 6 i:46, pairs changed 2
# fullSet, iter: 6 i:47, pairs changed 2
# L==H
# fullSet, iter: 6 i:48, pairs changed 2
# fullSet, iter: 6 i:49, pairs changed 2
# fullSet, iter: 6 i:50, pairs changed 2
# fullSet, iter: 6 i:51, pairs changed 2
# fullSet, iter: 6 i:52, pairs changed 2
# L==H
# fullSet, iter: 6 i:53, pairs changed 2
# fullSet, iter: 6 i:54, pairs changed 2
# fullSet, iter: 6 i:55, pairs changed 2
# fullSet, iter: 6 i:56, pairs changed 2
# fullSet, iter: 6 i:57, pairs changed 2
# L==H
# fullSet, iter: 6 i:58, pairs changed 2
# fullSet, iter: 6 i:59, pairs changed 2
# fullSet, iter: 6 i:60, pairs changed 2
# fullSet, iter: 6 i:61, pairs changed 2
# fullSet, iter: 6 i:62, pairs changed 2
# fullSet, iter: 6 i:63, pairs changed 2
# fullSet, iter: 6 i:64, pairs changed 2
# L==H
# fullSet, iter: 6 i:65, pairs changed 2
# fullSet, iter: 6 i:66, pairs changed 2
# fullSet, iter: 6 i:67, pairs changed 2
# fullSet, iter: 6 i:68, pairs changed 2
# fullSet, iter: 6 i:69, pairs changed 2
# fullSet, iter: 6 i:70, pairs changed 2
# fullSet, iter: 6 i:71, pairs changed 2
# fullSet, iter: 6 i:72, pairs changed 2
# fullSet, iter: 6 i:73, pairs changed 2
# fullSet, iter: 6 i:74, pairs changed 2
# fullSet, iter: 6 i:75, pairs changed 2
# j not moving enough
# fullSet, iter: 6 i:76, pairs changed 2
# fullSet, iter: 6 i:77, pairs changed 2
# L==H
# fullSet, iter: 6 i:78, pairs changed 2
# fullSet, iter: 6 i:79, pairs changed 2
# fullSet, iter: 6 i:80, pairs changed 2
# fullSet, iter: 6 i:81, pairs changed 2
# L==H
# fullSet, iter: 6 i:82, pairs changed 2
# fullSet, iter: 6 i:83, pairs changed 2
# fullSet, iter: 6 i:84, pairs changed 2
# L==H
# fullSet, iter: 6 i:85, pairs changed 2
# fullSet, iter: 6 i:86, pairs changed 2
# j not moving enough
# fullSet, iter: 6 i:87, pairs changed 2
# fullSet, iter: 6 i:88, pairs changed 2
# fullSet, iter: 6 i:89, pairs changed 2
# L==H
# fullSet, iter: 6 i:90, pairs changed 2
# L==H
# fullSet, iter: 6 i:91, pairs changed 2
# L==H
# fullSet, iter: 6 i:92, pairs changed 2
# fullSet, iter: 6 i:93, pairs changed 2
# fullSet, iter: 6 i:94, pairs changed 2
# fullSet, iter: 6 i:95, pairs changed 2
# L==H
# fullSet, iter: 6 i:96, pairs changed 2
# fullSet, iter: 6 i:97, pairs changed 2
# fullSet, iter: 6 i:98, pairs changed 2
# fullSet, iter: 6 i:99, pairs changed 2
# iteration number: 7
# j not moving enough
# non-bound, iter: 7 i:0, pairs changed 0
# j not moving enough
# non-bound, iter: 7 i:3, pairs changed 0
# j not moving enough
# non-bound, iter: 7 i:7, pairs changed 0
# j not moving enough
# non-bound, iter: 7 i:11, pairs changed 0
# j not moving enough
# non-bound, iter: 7 i:13, pairs changed 0
# j not moving enough
# non-bound, iter: 7 i:14, pairs changed 0
# j not moving enough
# non-bound, iter: 7 i:16, pairs changed 0
# j not moving enough
# non-bound, iter: 7 i:17, pairs changed 0
# j not moving enough
# non-bound, iter: 7 i:18, pairs changed 0
# j not moving enough
# non-bound, iter: 7 i:19, pairs changed 0
# j not moving enough
# non-bound, iter: 7 i:21, pairs changed 0
# j not moving enough
# non-bound, iter: 7 i:23, pairs changed 0
# j not moving enough
# non-bound, iter: 7 i:26, pairs changed 0
# j not moving enough
# non-bound, iter: 7 i:27, pairs changed 0
# j not moving enough
# non-bound, iter: 7 i:28, pairs changed 0
# j not moving enough
# non-bound, iter: 7 i:29, pairs changed 0
# j not moving enough
# non-bound, iter: 7 i:31, pairs changed 0
# j not moving enough
# non-bound, iter: 7 i:34, pairs changed 0
# j not moving enough
# non-bound, iter: 7 i:36, pairs changed 0
# j not moving enough
# non-bound, iter: 7 i:41, pairs changed 0
# non-bound, iter: 7 i:45, pairs changed 0
# j not moving enough
# non-bound, iter: 7 i:76, pairs changed 0
# j not moving enough
# non-bound, iter: 7 i:87, pairs changed 0
# iteration number: 8
# j not moving enough
# fullSet, iter: 8 i:0, pairs changed 0
# fullSet, iter: 8 i:1, pairs changed 0
# fullSet, iter: 8 i:2, pairs changed 0
# j not moving enough
# fullSet, iter: 8 i:3, pairs changed 0
# fullSet, iter: 8 i:4, pairs changed 0
# fullSet, iter: 8 i:5, pairs changed 0
# L==H
# fullSet, iter: 8 i:6, pairs changed 0
# j not moving enough
# fullSet, iter: 8 i:7, pairs changed 0
# fullSet, iter: 8 i:8, pairs changed 0
# fullSet, iter: 8 i:9, pairs changed 0
# fullSet, iter: 8 i:10, pairs changed 0
# j not moving enough
# fullSet, iter: 8 i:11, pairs changed 0
# fullSet, iter: 8 i:12, pairs changed 0
# j not moving enough
# fullSet, iter: 8 i:13, pairs changed 0
# j not moving enough
# fullSet, iter: 8 i:14, pairs changed 0
# fullSet, iter: 8 i:15, pairs changed 0
# j not moving enough
# fullSet, iter: 8 i:16, pairs changed 0
# j not moving enough
# fullSet, iter: 8 i:17, pairs changed 0
# j not moving enough
# fullSet, iter: 8 i:18, pairs changed 0
# j not moving enough
# fullSet, iter: 8 i:19, pairs changed 0
# fullSet, iter: 8 i:20, pairs changed 0
# j not moving enough
# fullSet, iter: 8 i:21, pairs changed 0
# fullSet, iter: 8 i:22, pairs changed 0
# j not moving enough
# fullSet, iter: 8 i:23, pairs changed 0
# fullSet, iter: 8 i:24, pairs changed 0
# fullSet, iter: 8 i:25, pairs changed 0
# j not moving enough
# fullSet, iter: 8 i:26, pairs changed 0
# j not moving enough
# fullSet, iter: 8 i:27, pairs changed 0
# j not moving enough
# fullSet, iter: 8 i:28, pairs changed 0
# j not moving enough
# fullSet, iter: 8 i:29, pairs changed 0
# L==H
# fullSet, iter: 8 i:30, pairs changed 0
# j not moving enough
# fullSet, iter: 8 i:31, pairs changed 0
# fullSet, iter: 8 i:32, pairs changed 0
# fullSet, iter: 8 i:33, pairs changed 0
# j not moving enough
# fullSet, iter: 8 i:34, pairs changed 0
# fullSet, iter: 8 i:35, pairs changed 0
# j not moving enough
# fullSet, iter: 8 i:36, pairs changed 0
# fullSet, iter: 8 i:37, pairs changed 0
# L==H
# fullSet, iter: 8 i:38, pairs changed 0
# fullSet, iter: 8 i:39, pairs changed 0
# fullSet, iter: 8 i:40, pairs changed 0
# j not moving enough
# fullSet, iter: 8 i:41, pairs changed 0
# L==H
# fullSet, iter: 8 i:42, pairs changed 0
# L==H
# fullSet, iter: 8 i:43, pairs changed 0
# fullSet, iter: 8 i:44, pairs changed 0
# fullSet, iter: 8 i:45, pairs changed 0
# L==H
# fullSet, iter: 8 i:46, pairs changed 0
# fullSet, iter: 8 i:47, pairs changed 0
# L==H
# fullSet, iter: 8 i:48, pairs changed 0
# fullSet, iter: 8 i:49, pairs changed 0
# fullSet, iter: 8 i:50, pairs changed 0
# fullSet, iter: 8 i:51, pairs changed 0
# fullSet, iter: 8 i:52, pairs changed 0
# L==H
# fullSet, iter: 8 i:53, pairs changed 0
# fullSet, iter: 8 i:54, pairs changed 0
# fullSet, iter: 8 i:55, pairs changed 0
# fullSet, iter: 8 i:56, pairs changed 0
# fullSet, iter: 8 i:57, pairs changed 0
# L==H
# fullSet, iter: 8 i:58, pairs changed 0
# fullSet, iter: 8 i:59, pairs changed 0
# fullSet, iter: 8 i:60, pairs changed 0
# fullSet, iter: 8 i:61, pairs changed 0
# fullSet, iter: 8 i:62, pairs changed 0
# fullSet, iter: 8 i:63, pairs changed 0
# fullSet, iter: 8 i:64, pairs changed 0
# L==H
# fullSet, iter: 8 i:65, pairs changed 0
# fullSet, iter: 8 i:66, pairs changed 0
# fullSet, iter: 8 i:67, pairs changed 0
# fullSet, iter: 8 i:68, pairs changed 0
# fullSet, iter: 8 i:69, pairs changed 0
# fullSet, iter: 8 i:70, pairs changed 0
# fullSet, iter: 8 i:71, pairs changed 0
# fullSet, iter: 8 i:72, pairs changed 0
# fullSet, iter: 8 i:73, pairs changed 0
# fullSet, iter: 8 i:74, pairs changed 0
# fullSet, iter: 8 i:75, pairs changed 0
# j not moving enough
# fullSet, iter: 8 i:76, pairs changed 0
# fullSet, iter: 8 i:77, pairs changed 0
# L==H
# fullSet, iter: 8 i:78, pairs changed 0
# fullSet, iter: 8 i:79, pairs changed 0
# fullSet, iter: 8 i:80, pairs changed 0
# fullSet, iter: 8 i:81, pairs changed 0
# L==H
# fullSet, iter: 8 i:82, pairs changed 0
# fullSet, iter: 8 i:83, pairs changed 0
# fullSet, iter: 8 i:84, pairs changed 0
# L==H
# fullSet, iter: 8 i:85, pairs changed 0
# fullSet, iter: 8 i:86, pairs changed 0
# j not moving enough
# fullSet, iter: 8 i:87, pairs changed 0
# fullSet, iter: 8 i:88, pairs changed 0
# fullSet, iter: 8 i:89, pairs changed 0
# L==H
# fullSet, iter: 8 i:90, pairs changed 0
# L==H
# fullSet, iter: 8 i:91, pairs changed 0
# L==H
# fullSet, iter: 8 i:92, pairs changed 0
# fullSet, iter: 8 i:93, pairs changed 0
# fullSet, iter: 8 i:94, pairs changed 0
# fullSet, iter: 8 i:95, pairs changed 0
# L==H
# fullSet, iter: 8 i:96, pairs changed 0
# fullSet, iter: 8 i:97, pairs changed 0
# fullSet, iter: 8 i:98, pairs changed 0
# fullSet, iter: 8 i:99, pairs changed 0
# iteration number: 9
# there are 23 Support Vectors
# the training error rate is: 0.070000
# the test error rate is: 0.140000
